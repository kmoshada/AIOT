# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def read():
    return {"Hello": "World"}

if __name__ == "__main__":
    import uvicorn


    uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/anaconda3/envs/ML/lib/python3.11/site-packages/uvicorn/_compat.py:30, in asyncio_run(main, debug, loop_factory)
#      29 with asyncio.Runner(debug=debug, loop_factory=loop_factory) as runner:
# ---> 30     return runner.run(main)
#
# File ~/anaconda3/envs/ML/lib/python3.11/asyncio/runners.py:93, in Runner.run(self, coro, context)
#      91 if events._get_running_loop() is not None:
#      92     # fail fast with short traceback
# ---> 93     raise RuntimeError(
#      94         "Runner.run() cannot be called from a running event loop")
#      96 self._lazy_init()
#
# RuntimeError: Runner.run() cannot be called from a running event loop
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 12
# ...
